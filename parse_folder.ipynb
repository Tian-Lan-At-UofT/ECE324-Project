# %%
import os
import pandas
import math
import itertools
import numpy
import torch

#folder = "data"
#file_type = ".tbl"
#parse_folder("drive/MyDrive/ECE324/data", ".tbl")

def parse_folder(folder_name, suffix):
  filenames = os.listdir(folder_name)
  full_filenames = [os.path.join(folder_name, filename) for filename in filenames if filename.endswith(suffix)]
  print("Found", len(full_filenames), "files.\n")

  max_series_length = 0
  max_num_series = 0

  data_dict = dict()

  for file in full_filenames:
    whole_file = open(file, "r")
    star_id = whole_file.readline().strip()
    while((not (star_id.startswith("\\STAR_ID"))) or (star_id.startswith("\\STAR_ID_DEFINED"))):
      star_id = whole_file.readline().strip()
      if not star_id:
        print("Star ID not found for file", file)
        break
    
    line_contents = star_id.split("=", 1)
    star_name = (line_contents[-1]).strip().replace("\'", "").replace("\"", "")

    time_series = pandas.read_table(file, comment="\\", header=None, delim_whitespace=True, skipinitialspace=True)

    time_series = time_series.loc[pandas.isna(time_series[0]) != True]
    time_series = time_series.loc[pandas.isna(time_series[1]) != True]
    for row_label in time_series.index:
      if(pandas.isna(time_series.at[row_label, 2])):
        time_series.at[row_label, 2] = 0
    
    max_series_length = max(max_series_length, len(time_series))
    series_data = [(time_series[i]).tolist() for i in range(3)]

    if star_name in data_dict:
      (data_dict[star_name]).append(series_data)
    else:
      data_dict[star_name] = [series_data]
    max_num_series = max(max_num_series, len(data_dict[star_name]))

  stars_list = list()
  series_masks = dict()
  batched_series = [list() for batch in range(max_num_series)]

  for star in data_dict:
    stars_list.append(star)
    series_masks[star] = ([False]*len(data_dict[star]))+([True]*(max_num_series-len(data_dict[star])))

    for data_series in data_dict[star]:
      for data_axis in range(3):
        extend_factor = math.ceil(max_series_length/len(data_series[data_axis]))
        data_series[data_axis] = ((data_series[data_axis])*extend_factor)[:max_series_length]
        
    for data_series, into_batch in zip(itertools.cycle(data_dict[star]), range(max_num_series)):
      batched_series[into_batch].append(numpy.asarray(data_series, dtype=numpy.double))

  batches_list = [torch.from_numpy(numpy.asarray(batch, dtype=numpy.double)) for batch in batched_series]
    
  print("Longest data series:", max_series_length)
  return stars_list, series_masks, batches_list
# Out:
# Found 1071 files.
#
# Longest data series: 678
# (['HD 142',
#   'HD 4308',
#   'HD 4208',
#   'HD 3651',
#   '54 Psc',
#   'HD 2039',
#   'HD 2638',
#   'HD 37606',
#   'BD -17 0063',
#   'HD 2952',
#   '2MASS J00203151+3058293',
#   'GJ 3021',
#   'HD 166',
#   'HD 1461',
#   'HD 10697',
#   'HD 11506',
#   'HD 11964',
#   'HD 10780',
#   'HD 12661',
#   'HD 10700',
#   'HD 10476',
#   'HD 10647',
#   'HD 9826',
#   'ups And',
#   'Ups And',
#   'HR 458',
#   '2MASS J01343317+6856535',
#   'HD 8574',
#   'HD 6434',
#   'HD 5608',
#   'HD 7924',
#   'HD 5319',
#   'HD 4614',
#   'HD 4203',
#   'HD 4628',
#   'HD 4313',
#   'HD 4732',
#   'HD 22781',
#   'HD 22484',
#   'HD 23079',
#   'HD 22049',
#   'HD 23127',
#   'Epsilon Eridani',
#   'HD 20367',
#   'HD 19994',
#   'HD 20630',
#   'HD 20782',
#   'HD 20868',
#   'HIP 14810',
#   'HD 19373',
#   'HD 17156',
#   'Iota Hor',
#   'HD 17925',
#   'HIP 12961',
#   'Iota Horologii',
#   'HD 16760',
#   '81 Cet',
#   'HD 17051',
#   'HD 16175',
#   '30 Ari B',
#   'HD 16417',
#   'Gl 86',
#   '75 Cet',
#   'HD 16160',
#   'WASP-33',
#   'HD 16141',
#   '79 Ceti',
#   'GJ 86',
#   'alpha Ari',
#   'HD 38529',
#   'HD 37124',
#   'HD 37605',
#   'HD 39091',
#   'HD 37394',
#   'pi Men',
#   'HD 33636',
#   'HD 33283',
#   'HD 32923',
#   'HD 32147',
#   'HD 32518',
#   'HD 35956A',
#   'HD 34411',
#   'HD 30652',
#   'HD 31253',
#   '2MASS J04425581+1857285',
#   'HD 30495',
#   'HD 30562',
#   'GJ 179',
#   'GJ 176',
#   'HD 30177',
#   'HD 28185',
#   'Epsilon Reticuli',
#   'HD 27894',
#   'Epsilon Tauri',
#   'HD 27442',
#   'HD 23596',
#   'HD 23249',
#   'HD 25457',
#   'HD 26965',
#   'HD 47536',
#   'HD 50499',
#   'HD 48682',
#   'HD 48265',
#   'HD 49674',
#   '7 CMa',
#   'HD 47186',
#   'HD 46375',
#   '6 Lyn',
#   'HD 45652',
#   'HD 45350',
#   'HD 43848',
#   'HD 43691',
#   'HD 45364',
#   'HD 43042',
#   'HD 43587',
#   'HD 40979',
#   'HD 38801',
#   'HD 41004A',
#   'HD 40307',
#   'Beta Gem',
#   '2MASS J07343908+2220156',
#   'HD 63454',
#   'HD 60532',
#   '2MASS J07252689+0451029',
#   'HD 52265',
#   'HD 50554',
#   'HD 72905',
#   'HD 74156',
#   'HD 73267',
#   'HD 73526',
#   'HD 72659',
#   'HD 69897',
#   'HD 70642',
#   'omicron UMa',
#   'HD 69830',
#   'HD 68988',
#   'HD 66428',
#   'HD 67228',
#   'HD 65216',
#   'HD 64468',
#   'Pollux',
#   'HD 80606',
#   'HD 79498',
#   'HD 76700',
#   'HD 75732',
#   'HD 75898',
#   'GJ 328',
#   'HD 75289',
#   '55 Cnc',
#   'HD 73534',
#   'HD 90839',
#   'HD 92788',
#   '47 UMa',
#   'HD 93083',
#   'HD 89744',
#   '24 Sextanis',
#   'HD 95089',
#   'Gamma 1 Leo',
#   'HD 89307',
#   'HD 88133',
#   'HD 87883',
#   'HD 86264',
#   'HD 86728',
#   'BD -08 2823',
#   'HD 86226',
#   'HD 86081',
#   'HD 84737',
#   'HD 83443',
#   'HD 84117',
#   'HD 81688',
#   'HD 81040',
#   'HD 82943',
#   '11 Com',
#   'HD 104304',
#   'HD 106252',
#   'HD 104985',
#   'HD 102117',
#   'HD 102195',
#   'HD 102870',
#   'HD 102365',
#   'HD 101930',
#   '2MASS J11421096+2642251',
#   'HD 101501',
#   'HIP 57050',
#   'GJ 436',
#   'HD 100777',
#   'GJ 433',
#   'HD 100655',
#   'HD 99492',
#   'HD 99109',
#   '83 Leo B',
#   'HD 96127',
#   'HD 100623',
#   'HD 96167',
#   '2MASS J11041590+4000165',
#   'TW Hya',
#   'HD 95128',
#   'HD 114783',
#   'HD 114762',
#   'HD 115383',
#   'HD 114729',
#   '61 Vir',
#   'HW Vir',
#   'HD 111232',
#   'HD 114386',
#   'HD 109749',
#   'HD 114710',
#   'HD 114613',
#   'HD 109358',
#   'HD 108874',
#   'HD 108147',
#   'HD 107148',
#   'HD 130322',
#   'HD 132406',
#   'HD 131156',
#   'HD 131977',
#   'HD 129445',
#   'HD 128311',
#   'HD 128167',
#   'HD 121504',
#   'HD 125612',
#   'HD 120136',
#   'Proxima Cen',
#   'HD 117207',
#   'Tau Boo',
#   'HD 120084',
#   'HD 118203',
#   '2MASS J13375120+4808174',
#   'HD 117618',
#   '70 Vir',
#   'HD 117176',
#   'HD 115617',
#   '14 Her',
#   'Rho CrB',
#   'HD 142022A',
#   'HD 143361',
#   'HD 145457',
#   'HD 142415',
#   'epsilon CrB',
#   'HD 330075',
#   'HD 142860',
#   'omega Ser',
#   'HD 142373',
#   'HD 141937',
#   'Kappa CrB',
#   'HD 141004',
#   'Gl 581',
#   'Iota Draconis',
#   'omicron CrB',
#   'HD 139357',
#   'HD 136352',
#   'HD 137510',
#   'HD 136118',
#   'HD 136418',
#   'GJ 581',
#   '11 UMi',
#   'HD 134083',
#   'HD 131664',
#   'HD 134987',
#   'HD 132563 B',
#   'GJ 649',
#   '2MASS J16404891+3618596',
#   'HD 149661',
#   'HD 149382',
#   'HD 154345',
#   'HD 152079',
#   'HD 149026',
#   'HD 149143',
#   'HD 148427',
#   'HD 147513',
#   'HAT-P-2',
#   'HD 147506',
#   'HD 146233',
#   'HD 145377',
#   'HIP 79431',
#   'HD 168443',
#   'HD 164427',
#   'HD 167042',
#   'HD 164604',
#   'HD 164922',
#   'HD 164509',
#   'HD 162020',
#   'HD 161797',
#   'HD 163607',
#   'mu Arae',
#   'GJ 676 A',
#   'HD 159868',
#   'HD 160691',
#   'GJ 674',
#   'HD 157214',
#   'mu Ara',
#   'HD 156279',
#   'HD 155358',
#   'HD 154672',
#   'HD 154857',
#   'HD 153950',
#   'HD 179949',
#   'HD 180314',
#   'HD 178911B',
#   'HD 179079',
#   'HD 173667',
#   'HD 173416',
#   'HD 175167',
#   'HD 177830',
#   'HD 172051',
#   'HD 175541',
#   'HD 170469',
#   'HD 169830',
#   'HD 169822',
#   '42 Dra',
#   'HD 168746',
#   'HD 168723',
#   'HD 185269',
#   '16 Cyg B',
#   'HD 184860',
#   'HD 185395',
#   'Theta Cyg',
#   'HD 185144',
#   'HD 231701',
#   'HD 183263',
#   'HD 181342',
#   'HD 182572',
#   'HD 180902',
#   'HD 181433',
#   'HD 201092',
#   'HD 201091',
#   'HD 202206',
#   'BD +14 4559',
#   '18 Del',
#   'HD 196050',
#   'HD 196885',
#   'HD 195019',
#   'HD 196885A',
#   'HD 192263',
#   'HD 192310',
#   'HD 192699',
#   'HD 191760',
#   'HD 191408',
#   'HD 190647',
#   'HD 190228',
#   'GJ 777 A',
#   'HD 190360',
#   'HD 189733',
#   'HAT-P-11',
#   'HD 188512',
#   'HD 187691',
#   'HD 188015',
#   'Xi Aql',
#   'HD 187123',
#   'HD 189123',
#   'HD 187085',
#   'HD 216437',
#   'Tau 1 Gruis',
#   'HD 216770',
#   'GJ 876',
#   'Rho Ind',
#   '51 Peg',
#   'HD 215648',
#   'HD 213240',
#   'HD 212301',
#   'HD 212771',
#   'HD 210702',
#   'HD 210277',
#   'HD 210302',
#   'GJ 849',
#   'HD 209458',
#   'HD 205739',
#   'HD 208487',
#   'HD 206610',
#   'GJ 832',
#   'HD 207832',
#   'HD 208527',
#   'HD 204313',
#   'HD 220773',
#   'HD 240237',
#   'HD 220074',
#   'HD 219134',
#   'HD 218566',
#   'HD 219828',
#   'HD 217107',
#   'HD 217014',
#   'BD -10 3166',
#   'XO-1',
#   'TrES-1',
#   '2MASS J19071403+4918590',
#   'TrES-2',
#   'OGLE-TR-111',
#   'OOGLE-TR-113',
#   'OGLE-TR-113',
#   'OGLE-TR-132',
#   'TrES-3',
#   'OGLE-TR-56',
#   'OGLE-TR-10',
#   'GJ 3634',
#   'HD 41004B',
#   'GJ 1214',
#   'GJ 317',
#   'GJ 3470',
#   'Gamma Cephei',
#   'HD 222368',
#   'HD 224693',
#   'HD 222582',
#   'Gamma Ceph',
#   '14 And',
#   'HD 221287',
#   'WASP-3',
#   'WASP-5',
#   'OGLE-TR-182',
#   'WASP-4',
#   'NGC 4349 127',
#   'Lupus-TR-3',
#   'OGLE-TR-211',
#   'HAT-P-6',
#   'HAT-P-4',
#   'CoRoT-2',
#   'HD 171028',
#   'XO-3',
#   'HAT-P-5',
#   'TrES-4',
#   '2MASS J13442258+4801432',
#   'NGC 2423 No. 3',
#   'TrES 3',
#   '2MASS J02462210+4939110',
#   '2MASS J07480647+5013328',
#   'ChaHA 8',
#   'XO-2',
#   'CoRoT-1',
#   'HAT-P-3',
#   'WASP-2',
#   '2MASS J22574684+3840302',
#   '2MASS J00204007+3159239',
#   'HAT-P-1',
#   'WASP-1',
#   'WASP-17',
#   'Kepler-8',
#   'Kepler-7',
#   'HD 240210',
#   'WASP-16',
#   'WASP-19',
#   'HAT-P-13',
#   'Kepler-6',
#   'CoRoT 5',
#   'HAT-P-8',
#   'HAT-P-12',
#   'BD +20 2457',
#   'CoRoT-4',
#   'HAT-P-9',
#   'OGLE2-TR-L9',
#   'CoRot-7',
#   'CoRoT-6',
#   'CoRoT 7',
#   'CoRoT-3',
#   'CoRoT 3',
#   'XO-5',
#   'XO-4',
#   'WASP-13',
#   'WASP-14',
#   'WASP-11',
#   'WASP-12',
#   'WASP-15',
#   'HAT-P-7',
#   'WASP-6',
#   'WASP-10',
#   'WASP-7',
#   'HAT-P-10',
#   'WASP-39',
#   'Kepler-40',
#   'WASP-37',
#   '2MASS J19024305+5014286',
#   'HAT-P-27',
#   'HAT-P-26',
#   'WASP-32',
#   'WASP-38',
#   'HAT-P-24',
#   'HAT-P-18',
#   'HAT-P-20',
#   'HAT-P-21',
#   'HAT-P-25',
#   'CoRoT-8',
#   'HAT-P-22',
#   'HAT-P-23',
#   'WASP-36',
#   'WASP-21',
#   'HAT-P-15',
#   'WASP-24',
#   'HAT-P-16',
#   'WASP-25',
#   'BD +20 1790',
#   'WASP-22',
#   'HAT-P-14',
#   'WASP-26',
#   'Kepler-74',
#   '2MASS J18561431+4431052',
#   '2MASS J19254039+3840204',
#   'Kepler-68',
#   'CoRoT-23',
#   'Kepler-12',
#   'HATS-P-37',
#   'Qatar-2',
#   'Kepler-44',
#   'HATS-P-36',
#   'HATS-P-35',
#   'Kepler-20',
#   'Kepler-43',
#   'Kepler-77',
#   'Kepler-100',
#   'CoRoT-18',
#   'TrES-5',
#   'Kepler-15',
#   'CoRoT-19',
#   'Kepler-17',
#   'HAT-P-28',
#   'HAT-P-29',
#   'WASP-45',
#   'HATS-P-30',
#   'WASP-43',
#   'WASP-44',
#   'WASP-46',
#   'WASP-77 A',
#   'WASP-52',
#   'WASP-64',
#   'WASP-59',
#   'WASP-57',
#   'WASP-72',
#   'WASP-58',
#   'WASP-61',
#   'WASP-54',
#   'WASP-62',
#   'WASP-67',
#   'WASP-66',
#   'WASP-63',
#   'WASP-56',
#   'WASP-55',
#   'WASP-42',
#   'HAT-P-40',
#   'HAT-P-41',
#   'WASP-78',
#   'Pr 211',
#   'HAT-P-39',
#   'Pr 201',
#   'WASP-79',
#   'HATS-1',
#   'Kepler-75',
#   '2MASS J19344300+4651099',
#   'CoRoT-16',
#   '2MASS J19240775+4902249',
#   'CoRoT-26',
#   'HATS-2',
#   'KELT-6',
#   'CoRoT-27',
#   'HAT-P-49',
#   'CoRoT-25'],
#  {'11 Com': [False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   '11 UMi': [False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   '14 And': [False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   '14 Her': [False,
#    False,
#    False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   '16 Cyg B': [False,
#    False,
#    False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   '18 Del': [False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   '24 Sextanis': [False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   '2MASS J00203151+3058293': [False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   '2MASS J00204007+3159239': [False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   '2MASS J01343317+6856535': [False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   '2MASS J02462210+4939110': [False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   '2MASS J04425581+1857285': [False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   '2MASS J07252689+0451029': [False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   '2MASS J07343908+2220156': [False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   '2MASS J07480647+5013328': [False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   '2MASS J11041590+4000165': [False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   '2MASS J11421096+2642251': [False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   '2MASS J13375120+4808174': [False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   '2MASS J13442258+4801432': [False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   '2MASS J16404891+3618596': [False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   '2MASS J18561431+4431052': [False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   '2MASS J19024305+5014286': [False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   '2MASS J19071403+4918590': [False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   '2MASS J19240775+4902249': [False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   '2MASS J19254039+3840204': [False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   '2MASS J19344300+4651099': [False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   '2MASS J22574684+3840302': [False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   '30 Ari B': [False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   '42 Dra': [False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   '47 UMa': [False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True],
#   '51 Peg': [False,
#    False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   '54 Psc': [False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   '55 Cnc': [False,
#    False,
#    False,
#    False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   '6 Lyn': [False, True, True, True, True, True, True, True, True, True, True],
#   '61 Vir': [False,
#    False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   '7 CMa': [False, True, True, True, True, True, True, True, True, True, True],
#   '70 Vir': [False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   '75 Cet': [False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   '79 Ceti': [False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   '81 Cet': [False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   '83 Leo B': [False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'BD +14 4559': [False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'BD +20 1790': [False,
#    False,
#    False,
#    False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'BD +20 2457': [False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'BD -08 2823': [False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'BD -10 3166': [False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'BD -17 0063': [False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'Beta Gem': [False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'ChaHA 8': [False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'CoRoT 3': [False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'CoRoT 5': [False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'CoRoT 7': [False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'CoRoT-1': [False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'CoRoT-16': [False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'CoRoT-18': [False,
#    False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'CoRoT-19': [False,
#    False,
#    False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'CoRoT-2': [False,
#    False,
#    False,
#    False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'CoRoT-23': [False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'CoRoT-25': [False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'CoRoT-26': [False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'CoRoT-27': [False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'CoRoT-3': [False,
#    False,
#    False,
#    False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'CoRoT-4': [False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'CoRoT-6': [False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'CoRoT-8': [False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'CoRot-7': [False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'Epsilon Eridani': [False,
#    False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'Epsilon Reticuli': [False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'Epsilon Tauri': [False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'GJ 1214': [False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'GJ 176': [False,
#    False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'GJ 179': [False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'GJ 3021': [False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'GJ 317': [False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'GJ 328': [False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'GJ 3470': [False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'GJ 3634': [False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'GJ 433': [False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'GJ 436': [False,
#    False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'GJ 581': [False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'GJ 649': [False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'GJ 674': [False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'GJ 676 A': [False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'GJ 777 A': [False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'GJ 832': [False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'GJ 849': [False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'GJ 86': [False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'GJ 876': [False,
#    False,
#    False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'Gamma 1 Leo': [False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'Gamma Ceph': [False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'Gamma Cephei': [False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False],
#   'Gl 581': [False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'Gl 86': [False, True, True, True, True, True, True, True, True, True, True],
#   'HAT-P-1': [False,
#    False,
#    False,
#    False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HAT-P-10': [False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HAT-P-11': [False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HAT-P-12': [False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HAT-P-13': [False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HAT-P-14': [False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HAT-P-15': [False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HAT-P-16': [False,
#    False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HAT-P-18': [False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HAT-P-2': [False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HAT-P-20': [False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HAT-P-21': [False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HAT-P-22': [False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HAT-P-23': [False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HAT-P-24': [False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HAT-P-25': [False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HAT-P-26': [False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HAT-P-27': [False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HAT-P-28': [False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HAT-P-29': [False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HAT-P-3': [False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HAT-P-39': [False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HAT-P-4': [False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HAT-P-40': [False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HAT-P-41': [False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HAT-P-49': [False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HAT-P-5': [False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HAT-P-6': [False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HAT-P-7': [False,
#    False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HAT-P-8': [False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HAT-P-9': [False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HATS-1': [False,
#    False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HATS-2': [False,
#    False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HATS-P-30': [False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HATS-P-35': [False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HATS-P-36': [False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HATS-P-37': [False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 100623': [False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 100655': [False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 100777': [False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 101501': [False,
#    False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 101930': [False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 102117': [False,
#    False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 102195': [False,
#    False,
#    False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 102365': [False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 102870': [False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 104304': [False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 10476': [False,
#    False,
#    False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 104985': [False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 106252': [False,
#    False,
#    False,
#    False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 10647': [False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 10697': [False,
#    False,
#    False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 10700': [False,
#    False,
#    False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 107148': [False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 10780': [False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 108147': [False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 108874': [False,
#    False,
#    False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 109358': [False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 109749': [False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 111232': [False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 114386': [False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 114613': [False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 114710': [False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 114729': [False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 114762': [False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 114783': [False,
#    False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 11506': [False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 115383': [False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 115617': [False,
#    False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 117176': [False,
#    False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 117207': [False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 117618': [False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 118203': [False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 11964': [False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 120084': [False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 120136': [False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 121504': [False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 125612': [False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 12661': [False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    True,
#    True,
#    True],
#   'HD 128167': [False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 128311': [False,
#    False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 129445': [False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 130322': [False,
#    False,
#    False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 131156': [False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 131664': [False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 131977': [False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 132406': [False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 132563 B': [False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 134083': [False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 134987': [False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 136118': [False,
#    False,
#    False,
#    False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 136352': [False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 136418': [False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 137510': [False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 139357': [False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 141004': [False,
#    False,
#    False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 141937': [False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 142': [False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 142022A': [False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 142373': [False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 142415': [False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 142860': [False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 143361': [False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 145377': [False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 145457': [False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 1461': [False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 146233': [False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 147506': [False,
#    False,
#    False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 147513': [False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 148427': [False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 149026': [False,
#    False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 149143': [False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 149382': [False,
#    False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 149661': [False,
#    False,
#    False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 152079': [False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 153950': [False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 154345': [False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 154672': [False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 154857': [False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 155358': [False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 156279': [False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 157214': [False,
#    False,
#    False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 159868': [False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 160691': [False,
#    False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 16141': [False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 16160': [False,
#    False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 16175': [False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 161797': [False,
#    False,
#    False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 162020': [False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 163607': [False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 16417': [False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 164427': [False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 164509': [False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 164604': [False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 164922': [False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 166': [False,
#    False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 167042': [False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 16760': [False,
#    False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 168443': [False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 168723': [False,
#    False,
#    False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 168746': [False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 169822': [False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 169830': [False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 170469': [False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 17051': [False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 171028': [False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 17156': [False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    True,
#    True,
#    True],
#   'HD 172051': [False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 173416': [False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 173667': [False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 175167': [False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 175541': [False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 177830': [False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 178911B': [False,
#    False,
#    False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 179079': [False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 17925': [False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 179949': [False,
#    False,
#    False,
#    False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 180314': [False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 180902': [False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 181342': [False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 181433': [False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 182572': [False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 183263': [False,
#    False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 184860': [False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 185144': [False,
#    False,
#    False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 185269': [False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 185395': [False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 187085': [False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 187123': [False,
#    False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 187691': [False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 188015': [False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 188512': [False,
#    False,
#    False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 189123': [False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 189733': [False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 190228': [False,
#    False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 190360': [False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 190647': [False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 191408': [False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 191760': [False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 192263': [False,
#    False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 192310': [False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 192699': [False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 19373': [False,
#    False,
#    False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 195019': [False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    True,
#    True,
#    True,
#    True],
#   'HD 196050': [False,
#    False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 196885': [False,
#    False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 196885A': [False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 19994': [False,
#    False,
#    False,
#    False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 201091': [False,
#    False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 201092': [False,
#    False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 202206': [False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 20367': [False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 2039': [False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 204313': [False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 205739': [False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 20630': [False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 206610': [False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 20782': [False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 207832': [False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 208487': [False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 208527': [False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 20868': [False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 209458': [False,
#    False,
#    False,
#    False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 210277': [False,
#    False,
#    False,
#    False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 210302': [False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 210702': [False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 212301': [False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 212771': [False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 213240': [False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 215648': [False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 216437': [False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 216770': [False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 217014': [False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 217107': [False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    True,
#    True],
#   'HD 218566': [False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 219134': [False,
#    False,
#    False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 219828': [False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 220074': [False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 22049': [False,
#    False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 220773': [False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 221287': [False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 222368': [False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 222582': [False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 224693': [False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 22484': [False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 22781': [False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 23079': [False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 23127': [False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 231701': [False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 23249': [False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 23596': [False,
#    False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 240210': [False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 240237': [False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 25457': [False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 2638': [False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 26965': [False,
#    False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 27442': [False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 27894': [False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 28185': [False,
#    False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 2952': [False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 30177': [False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 30495': [False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 30562': [False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 30652': [False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 31253': [False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 32147': [False,
#    False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 32518': [False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 32923': [False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 330075': [False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 33283': [False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 33636': [False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    True,
#    True,
#    True,
#    True],
#   'HD 34411': [False,
#    False,
#    False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 35956A': [False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True],
#   'HD 3651': [False,
#    False,
#    False,
#    False,
#    False,
# ...
#            [ 7.5000e+00,  7.5000e+00,  1.4500e+01,  ...,  7.5000e+00,
#              7.5000e+00,  1.4500e+01]],
#
#           [[ 2.4529e+06,  2.4529e+06,  2.4529e+06,  ...,  2.4533e+06,
#              2.4533e+06,  2.4533e+06],
#            [ 9.5245e+04,  9.5251e+04,  9.5241e+04,  ...,  9.5249e+04,
#              9.5250e+04,  9.5238e+04],
#            [ 1.3600e+00,  1.4400e+00,  1.5700e+00,  ...,  9.4000e-01,
#              9.4000e-01,  1.1600e+00]],
#
#           [[ 2.4504e+06,  2.4507e+06,  2.4508e+06,  ...,  2.4516e+06,
#              2.4516e+06,  2.4518e+06],
#            [ 1.1800e+01, -1.0800e+01, -8.6000e+00,  ..., -1.6800e+01,
#             -1.6100e+01,  1.2300e+01],
#            [ 2.7000e+00,  2.7000e+00,  3.6000e+00,  ...,  2.9000e+00,
#              3.2000e+00,  2.5000e+00]],
#
#           ...,
#
#           [[ 2.4561e+06,  2.4561e+06,  2.4561e+06,  ...,  2.4562e+06,
#              2.4561e+06,  2.4561e+06],
#            [-5.4157e+03, -2.8896e+03, -5.0221e+03,  ..., -4.0204e+03,
#             -5.4157e+03, -2.8896e+03],
#            [ 9.7100e+01,  7.5600e+01,  2.0880e+02,  ...,  8.3300e+01,
#              9.7100e+01,  7.5600e+01]],
#
#           [[ 2.4561e+06,  2.4562e+06,  2.4562e+06,  ...,  2.4562e+06,
#              2.4562e+06,  2.4562e+06],
#            [ 2.1800e+02, -9.6000e+01, -6.1000e+01,  ...,  3.0300e+02,
#              3.3700e+02,  1.1300e+02],
#            [ 5.2000e+01,  6.8000e+01,  5.2000e+01,  ...,  5.8000e+01,
#              5.5000e+01,  1.9000e+01]],
#
#           [[ 2.4550e+06,  2.4550e+06,  2.4550e+06,  ...,  2.4550e+06,
#              2.4558e+06,  2.4558e+06],
#            [ 1.8510e+01, -3.0200e+00,  8.1800e+00,  ..., -2.2830e+01,
#             -8.5200e+00,  7.6900e+00],
#            [ 1.1700e+01,  1.7800e+01,  1.6800e+01,  ...,  1.5200e+01,
#              1.5000e+01,  1.5300e+01]]], dtype=torch.float64),
#   tensor([[[ 2.4508e+06,  2.4511e+06,  2.4514e+06,  ...,  2.4530e+06,
#              2.4530e+06,  2.4530e+06],
#            [-1.9200e+01, -1.2400e+01,  3.2000e+01,  ..., -1.2200e+01,
#              2.0800e+01,  1.1300e+01],
#            [ 6.8000e+00,  7.8000e+00,  1.2000e+01,  ...,  7.9000e+00,
#              9.2000e+00,  9.0000e+00]],
#
#           [[ 2.4537e+06,  2.4537e+06,  2.4537e+06,  ...,  2.4540e+06,
#              2.4540e+06,  2.4540e+06],
#            [-3.0000e-01, -6.0000e-01,  2.8000e+00,  ...,  4.0000e-01,
#             -2.3000e+00, -4.0000e-01],
#            [ 9.0000e-01,  9.0000e-01,  8.0000e-01,  ...,  1.0000e+00,
#              9.0000e-01,  8.0000e-01]],
#
#           [[ 2.4504e+06,  2.4507e+06,  2.4508e+06,  ...,  2.4514e+06,
#              2.4514e+06,  2.4515e+06],
#            [ 8.5000e+00, -1.7400e+01, -1.9600e+01,  ..., -1.8600e+01,
#             -2.6600e+01, -1.3500e+01],
#            [ 3.5000e+00,  3.6000e+00,  5.6000e+00,  ...,  3.8000e+00,
#              4.0000e+00,  4.7000e+00]],
#
#           ...,
#
#           [[ 2.4561e+06,  2.4561e+06,  2.4561e+06,  ...,  2.4562e+06,
#              2.4561e+06,  2.4561e+06],
#            [-5.4157e+03, -2.8896e+03, -5.0221e+03,  ..., -4.0204e+03,
#             -5.4157e+03, -2.8896e+03],
#            [ 9.7100e+01,  7.5600e+01,  2.0880e+02,  ...,  8.3300e+01,
#              9.7100e+01,  7.5600e+01]],
#
#           [[ 2.4562e+06,  2.4562e+06,  2.4562e+06,  ...,  2.4562e+06,
#              2.4562e+06,  2.4562e+06],
#            [ 2.4700e+02, -9.0000e+01,  2.3600e+02,  ..., -1.0600e+02,
#             -1.9200e+02, -2.2900e+02],
#            [ 2.6000e+01,  2.1000e+01,  1.1000e+01,  ...,  1.6000e+01,
#              1.3000e+01,  1.4000e+01]],
#
#           [[ 2.4550e+06,  2.4550e+06,  2.4550e+06,  ...,  2.4553e+06,
#              2.4553e+06,  2.4553e+06],
#            [-1.5388e+04, -1.5379e+04, -1.5388e+04,  ..., -1.5401e+04,
#             -1.5427e+04, -1.5404e+04],
#            [ 2.7400e+01,  5.8700e+01,  3.6600e+01,  ...,  3.1100e+01,
#              2.0700e+01,  5.0600e+01]]], dtype=torch.float64),
#   tensor([[[ 2.4508e+06,  2.4511e+06,  2.4514e+06,  ...,  2.4508e+06,
#              2.4511e+06,  2.4514e+06],
#            [-1.3100e+01, -1.6000e+01,  4.2600e+01,  ..., -1.3100e+01,
#             -1.6000e+01,  4.2600e+01],
#            [ 7.5000e+00,  7.5000e+00,  1.4500e+01,  ...,  7.5000e+00,
#              7.5000e+00,  1.4500e+01]],
#
#           [[ 2.4529e+06,  2.4529e+06,  2.4529e+06,  ...,  2.4533e+06,
#              2.4533e+06,  2.4533e+06],
#            [ 9.5245e+04,  9.5251e+04,  9.5241e+04,  ...,  9.5249e+04,
#              9.5250e+04,  9.5238e+04],
#            [ 1.3600e+00,  1.4400e+00,  1.5700e+00,  ...,  9.4000e-01,
#              9.4000e-01,  1.1600e+00]],
#
#           [[ 2.4504e+06,  2.4507e+06,  2.4508e+06,  ...,  2.4516e+06,
#              2.4516e+06,  2.4518e+06],
#            [ 1.1800e+01, -1.0800e+01, -8.6000e+00,  ..., -1.6800e+01,
#             -1.6100e+01,  1.2300e+01],
#            [ 2.7000e+00,  2.7000e+00,  3.6000e+00,  ...,  2.9000e+00,
#              3.2000e+00,  2.5000e+00]],
#
#           ...,
#
#           [[ 2.4561e+06,  2.4561e+06,  2.4561e+06,  ...,  2.4562e+06,
#              2.4561e+06,  2.4561e+06],
#            [-5.4157e+03, -2.8896e+03, -5.0221e+03,  ..., -4.0204e+03,
#             -5.4157e+03, -2.8896e+03],
#            [ 9.7100e+01,  7.5600e+01,  2.0880e+02,  ...,  8.3300e+01,
#              9.7100e+01,  7.5600e+01]],
#
#           [[ 2.4561e+06,  2.4562e+06,  2.4562e+06,  ...,  2.4562e+06,
#              2.4562e+06,  2.4562e+06],
#            [ 2.1800e+02, -9.6000e+01, -6.1000e+01,  ...,  3.0300e+02,
#              3.3700e+02,  1.1300e+02],
#            [ 5.2000e+01,  6.8000e+01,  5.2000e+01,  ...,  5.8000e+01,
#              5.5000e+01,  1.9000e+01]],
#
#           [[ 2.4550e+06,  2.4550e+06,  2.4550e+06,  ...,  2.4550e+06,
#              2.4558e+06,  2.4558e+06],
#            [ 1.8510e+01, -3.0200e+00,  8.1800e+00,  ..., -2.2830e+01,
#             -8.5200e+00,  7.6900e+00],
#            [ 1.1700e+01,  1.7800e+01,  1.6800e+01,  ...,  1.5200e+01,
#              1.5000e+01,  1.5300e+01]]], dtype=torch.float64),
#   tensor([[[ 2.4508e+06,  2.4511e+06,  2.4514e+06,  ...,  2.4530e+06,
#              2.4530e+06,  2.4530e+06],
#            [-1.9200e+01, -1.2400e+01,  3.2000e+01,  ..., -1.2200e+01,
#              2.0800e+01,  1.1300e+01],
#            [ 6.8000e+00,  7.8000e+00,  1.2000e+01,  ...,  7.9000e+00,
#              9.2000e+00,  9.0000e+00]],
#
#           [[ 2.4537e+06,  2.4537e+06,  2.4537e+06,  ...,  2.4540e+06,
#              2.4540e+06,  2.4540e+06],
#            [-3.0000e-01, -6.0000e-01,  2.8000e+00,  ...,  4.0000e-01,
#             -2.3000e+00, -4.0000e-01],
#            [ 9.0000e-01,  9.0000e-01,  8.0000e-01,  ...,  1.0000e+00,
#              9.0000e-01,  8.0000e-01]],
#
#           [[ 2.4504e+06,  2.4507e+06,  2.4508e+06,  ...,  2.4514e+06,
#              2.4514e+06,  2.4515e+06],
#            [ 8.5000e+00, -1.7400e+01, -1.9600e+01,  ..., -1.8600e+01,
#             -2.6600e+01, -1.3500e+01],
#            [ 3.5000e+00,  3.6000e+00,  5.6000e+00,  ...,  3.8000e+00,
#              4.0000e+00,  4.7000e+00]],
#
#           ...,
#
#           [[ 2.4561e+06,  2.4561e+06,  2.4561e+06,  ...,  2.4562e+06,
#              2.4561e+06,  2.4561e+06],
#            [-5.4157e+03, -2.8896e+03, -5.0221e+03,  ..., -4.0204e+03,
#             -5.4157e+03, -2.8896e+03],
#            [ 9.7100e+01,  7.5600e+01,  2.0880e+02,  ...,  8.3300e+01,
#              9.7100e+01,  7.5600e+01]],
#
#           [[ 2.4562e+06,  2.4562e+06,  2.4562e+06,  ...,  2.4562e+06,
#              2.4562e+06,  2.4562e+06],
#            [ 2.4700e+02, -9.0000e+01,  2.3600e+02,  ..., -1.0600e+02,
#             -1.9200e+02, -2.2900e+02],
#            [ 2.6000e+01,  2.1000e+01,  1.1000e+01,  ...,  1.6000e+01,
#              1.3000e+01,  1.4000e+01]],
#
#           [[ 2.4550e+06,  2.4550e+06,  2.4550e+06,  ...,  2.4553e+06,
#              2.4553e+06,  2.4553e+06],
#            [-1.5388e+04, -1.5379e+04, -1.5388e+04,  ..., -1.5401e+04,
#             -1.5427e+04, -1.5404e+04],
#            [ 2.7400e+01,  5.8700e+01,  3.6600e+01,  ...,  3.1100e+01,
#              2.0700e+01,  5.0600e+01]]], dtype=torch.float64),
#   tensor([[[ 2.4508e+06,  2.4511e+06,  2.4514e+06,  ...,  2.4508e+06,
#              2.4511e+06,  2.4514e+06],
#            [-1.3100e+01, -1.6000e+01,  4.2600e+01,  ..., -1.3100e+01,
#             -1.6000e+01,  4.2600e+01],
#            [ 7.5000e+00,  7.5000e+00,  1.4500e+01,  ...,  7.5000e+00,
#              7.5000e+00,  1.4500e+01]],
#
#           [[ 2.4529e+06,  2.4529e+06,  2.4529e+06,  ...,  2.4533e+06,
#              2.4533e+06,  2.4533e+06],
#            [ 9.5245e+04,  9.5251e+04,  9.5241e+04,  ...,  9.5249e+04,
#              9.5250e+04,  9.5238e+04],
#            [ 1.3600e+00,  1.4400e+00,  1.5700e+00,  ...,  9.4000e-01,
#              9.4000e-01,  1.1600e+00]],
#
#           [[ 2.4504e+06,  2.4507e+06,  2.4508e+06,  ...,  2.4516e+06,
#              2.4516e+06,  2.4518e+06],
#            [ 1.1800e+01, -1.0800e+01, -8.6000e+00,  ..., -1.6800e+01,
#             -1.6100e+01,  1.2300e+01],
#            [ 2.7000e+00,  2.7000e+00,  3.6000e+00,  ...,  2.9000e+00,
#              3.2000e+00,  2.5000e+00]],
#
#           ...,
#
#           [[ 2.4561e+06,  2.4561e+06,  2.4561e+06,  ...,  2.4562e+06,
#              2.4561e+06,  2.4561e+06],
#            [-5.4157e+03, -2.8896e+03, -5.0221e+03,  ..., -4.0204e+03,
#             -5.4157e+03, -2.8896e+03],
#            [ 9.7100e+01,  7.5600e+01,  2.0880e+02,  ...,  8.3300e+01,
#              9.7100e+01,  7.5600e+01]],
#
#           [[ 2.4561e+06,  2.4562e+06,  2.4562e+06,  ...,  2.4562e+06,
#              2.4562e+06,  2.4562e+06],
#            [ 2.1800e+02, -9.6000e+01, -6.1000e+01,  ...,  3.0300e+02,
#              3.3700e+02,  1.1300e+02],
#            [ 5.2000e+01,  6.8000e+01,  5.2000e+01,  ...,  5.8000e+01,
#              5.5000e+01,  1.9000e+01]],
#
#           [[ 2.4550e+06,  2.4550e+06,  2.4550e+06,  ...,  2.4550e+06,
#              2.4558e+06,  2.4558e+06],
#            [ 1.8510e+01, -3.0200e+00,  8.1800e+00,  ..., -2.2830e+01,
#             -8.5200e+00,  7.6900e+00],
#            [ 1.1700e+01,  1.7800e+01,  1.6800e+01,  ...,  1.5200e+01,
#              1.5000e+01,  1.5300e+01]]], dtype=torch.float64),
#   tensor([[[ 2.4508e+06,  2.4511e+06,  2.4514e+06,  ...,  2.4530e+06,
#              2.4530e+06,  2.4530e+06],
#            [-1.9200e+01, -1.2400e+01,  3.2000e+01,  ..., -1.2200e+01,
#              2.0800e+01,  1.1300e+01],
#            [ 6.8000e+00,  7.8000e+00,  1.2000e+01,  ...,  7.9000e+00,
#              9.2000e+00,  9.0000e+00]],
#
#           [[ 2.4537e+06,  2.4537e+06,  2.4537e+06,  ...,  2.4540e+06,
#              2.4540e+06,  2.4540e+06],
#            [-3.0000e-01, -6.0000e-01,  2.8000e+00,  ...,  4.0000e-01,
#             -2.3000e+00, -4.0000e-01],
#            [ 9.0000e-01,  9.0000e-01,  8.0000e-01,  ...,  1.0000e+00,
#              9.0000e-01,  8.0000e-01]],
#
#           [[ 2.4504e+06,  2.4507e+06,  2.4508e+06,  ...,  2.4514e+06,
#              2.4514e+06,  2.4515e+06],
#            [ 8.5000e+00, -1.7400e+01, -1.9600e+01,  ..., -1.8600e+01,
#             -2.6600e+01, -1.3500e+01],
#            [ 3.5000e+00,  3.6000e+00,  5.6000e+00,  ...,  3.8000e+00,
#              4.0000e+00,  4.7000e+00]],
#
#           ...,
#
#           [[ 2.4561e+06,  2.4561e+06,  2.4561e+06,  ...,  2.4562e+06,
#              2.4561e+06,  2.4561e+06],
#            [-5.4157e+03, -2.8896e+03, -5.0221e+03,  ..., -4.0204e+03,
#             -5.4157e+03, -2.8896e+03],
#            [ 9.7100e+01,  7.5600e+01,  2.0880e+02,  ...,  8.3300e+01,
#              9.7100e+01,  7.5600e+01]],
#
#           [[ 2.4562e+06,  2.4562e+06,  2.4562e+06,  ...,  2.4562e+06,
#              2.4562e+06,  2.4562e+06],
#            [ 2.4700e+02, -9.0000e+01,  2.3600e+02,  ..., -1.0600e+02,
#             -1.9200e+02, -2.2900e+02],
#            [ 2.6000e+01,  2.1000e+01,  1.1000e+01,  ...,  1.6000e+01,
#              1.3000e+01,  1.4000e+01]],
#
#           [[ 2.4550e+06,  2.4550e+06,  2.4550e+06,  ...,  2.4553e+06,
#              2.4553e+06,  2.4553e+06],
#            [-1.5388e+04, -1.5379e+04, -1.5388e+04,  ..., -1.5401e+04,
#             -1.5427e+04, -1.5404e+04],
#            [ 2.7400e+01,  5.8700e+01,  3.6600e+01,  ...,  3.1100e+01,
#              2.0700e+01,  5.0600e+01]]], dtype=torch.float64),
#   tensor([[[ 2.4508e+06,  2.4511e+06,  2.4514e+06,  ...,  2.4508e+06,
#              2.4511e+06,  2.4514e+06],
#            [-1.3100e+01, -1.6000e+01,  4.2600e+01,  ..., -1.3100e+01,
#             -1.6000e+01,  4.2600e+01],
#            [ 7.5000e+00,  7.5000e+00,  1.4500e+01,  ...,  7.5000e+00,
#              7.5000e+00,  1.4500e+01]],
#
#           [[ 2.4529e+06,  2.4529e+06,  2.4529e+06,  ...,  2.4533e+06,
#              2.4533e+06,  2.4533e+06],
#            [ 9.5245e+04,  9.5251e+04,  9.5241e+04,  ...,  9.5249e+04,
#              9.5250e+04,  9.5238e+04],
#            [ 1.3600e+00,  1.4400e+00,  1.5700e+00,  ...,  9.4000e-01,
#              9.4000e-01,  1.1600e+00]],
#
#           [[ 2.4504e+06,  2.4507e+06,  2.4508e+06,  ...,  2.4516e+06,
#              2.4516e+06,  2.4518e+06],
#            [ 1.1800e+01, -1.0800e+01, -8.6000e+00,  ..., -1.6800e+01,
#             -1.6100e+01,  1.2300e+01],
#            [ 2.7000e+00,  2.7000e+00,  3.6000e+00,  ...,  2.9000e+00,
#              3.2000e+00,  2.5000e+00]],
#
#           ...,
#
#           [[ 2.4561e+06,  2.4561e+06,  2.4561e+06,  ...,  2.4562e+06,
#              2.4561e+06,  2.4561e+06],
#            [-5.4157e+03, -2.8896e+03, -5.0221e+03,  ..., -4.0204e+03,
#             -5.4157e+03, -2.8896e+03],
#            [ 9.7100e+01,  7.5600e+01,  2.0880e+02,  ...,  8.3300e+01,
#              9.7100e+01,  7.5600e+01]],
#
#           [[ 2.4561e+06,  2.4562e+06,  2.4562e+06,  ...,  2.4562e+06,
#              2.4562e+06,  2.4562e+06],
#            [ 2.1800e+02, -9.6000e+01, -6.1000e+01,  ...,  3.0300e+02,
#              3.3700e+02,  1.1300e+02],
#            [ 5.2000e+01,  6.8000e+01,  5.2000e+01,  ...,  5.8000e+01,
#              5.5000e+01,  1.9000e+01]],
#
#           [[ 2.4550e+06,  2.4550e+06,  2.4550e+06,  ...,  2.4550e+06,
#              2.4558e+06,  2.4558e+06],
#            [ 1.8510e+01, -3.0200e+00,  8.1800e+00,  ..., -2.2830e+01,
#             -8.5200e+00,  7.6900e+00],
#            [ 1.1700e+01,  1.7800e+01,  1.6800e+01,  ...,  1.5200e+01,
#              1.5000e+01,  1.5300e+01]]], dtype=torch.float64),
#   tensor([[[ 2.4508e+06,  2.4511e+06,  2.4514e+06,  ...,  2.4530e+06,
#              2.4530e+06,  2.4530e+06],
#            [-1.9200e+01, -1.2400e+01,  3.2000e+01,  ..., -1.2200e+01,
#              2.0800e+01,  1.1300e+01],
#            [ 6.8000e+00,  7.8000e+00,  1.2000e+01,  ...,  7.9000e+00,
#              9.2000e+00,  9.0000e+00]],
#
#           [[ 2.4537e+06,  2.4537e+06,  2.4537e+06,  ...,  2.4540e+06,
#              2.4540e+06,  2.4540e+06],
#            [-3.0000e-01, -6.0000e-01,  2.8000e+00,  ...,  4.0000e-01,
#             -2.3000e+00, -4.0000e-01],
#            [ 9.0000e-01,  9.0000e-01,  8.0000e-01,  ...,  1.0000e+00,
#              9.0000e-01,  8.0000e-01]],
#
#           [[ 2.4504e+06,  2.4507e+06,  2.4508e+06,  ...,  2.4514e+06,
#              2.4514e+06,  2.4515e+06],
#            [ 8.5000e+00, -1.7400e+01, -1.9600e+01,  ..., -1.8600e+01,
#             -2.6600e+01, -1.3500e+01],
#            [ 3.5000e+00,  3.6000e+00,  5.6000e+00,  ...,  3.8000e+00,
#              4.0000e+00,  4.7000e+00]],
#
#           ...,
#
#           [[ 2.4561e+06,  2.4561e+06,  2.4561e+06,  ...,  2.4562e+06,
#              2.4561e+06,  2.4561e+06],
#            [-5.4157e+03, -2.8896e+03, -5.0221e+03,  ..., -4.0204e+03,
#             -5.4157e+03, -2.8896e+03],
#            [ 9.7100e+01,  7.5600e+01,  2.0880e+02,  ...,  8.3300e+01,
#              9.7100e+01,  7.5600e+01]],
#
#           [[ 2.4562e+06,  2.4562e+06,  2.4562e+06,  ...,  2.4562e+06,
#              2.4562e+06,  2.4562e+06],
#            [ 2.4700e+02, -9.0000e+01,  2.3600e+02,  ..., -1.0600e+02,
#             -1.9200e+02, -2.2900e+02],
#            [ 2.6000e+01,  2.1000e+01,  1.1000e+01,  ...,  1.6000e+01,
#              1.3000e+01,  1.4000e+01]],
#
#           [[ 2.4550e+06,  2.4550e+06,  2.4550e+06,  ...,  2.4553e+06,
#              2.4553e+06,  2.4553e+06],
#            [-1.5388e+04, -1.5379e+04, -1.5388e+04,  ..., -1.5401e+04,
#             -1.5427e+04, -1.5404e+04],
#            [ 2.7400e+01,  5.8700e+01,  3.6600e+01,  ...,  3.1100e+01,
#              2.0700e+01,  5.0600e+01]]], dtype=torch.float64)])
